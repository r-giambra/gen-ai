# %%
pip install openai

# %%
from openai import OpenAI # Import the OpenAI package

client = OpenAI(api_key="richiedi api key per mail")

completion = client.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": "Racconta una barzelletta sulle aziende di consulenza"}
  ]
)

print(completion.choices[0].message.content)
